# %%
import mysql.connector

mydb=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Password"
)
mydb

# %%
mycursor=mydb.cursor()
mycursor.execute("show databases")
for i in mycursor:
    print(i)
# Out:
# ('chocolate',)
# ('ciys',)
# ('class',)
# ('cte',)
# ('information_schema',)
# ('joinp',)
# ('mysql',)
# ('new',)
# ('pandas',)
# ('performance_schema',)
# ('prince',)
# ('school',)
# ('self',)
# ('spotify',)
# ('subq',)
# ('sys',)

# %%
mycursor.execute("select * from myntra_dataset_byscraping")
for i in mycursor:
    print(i)
# Out:
# ('WROGN', 'Men Loose Fit Cotton Jeans', 1374.0, 2499.0, 0.45, 4.2, 57.0)
# ('Flying Machine', 'Men Slim Fit Jeans', 1829.0, 2999.0, 0.39, 4.6, 5.0)
# ('Roadster', 'Men Pure Cotton Jeans', 974.0, 2499.0, 0.61, 3.6, 1100.0)
# ('Bene Kleed', 'Relaxed Fit Denim Jeans', 873.0, 2299.0, 0.62, 4.0, 4800.0)
# ('Levis', 'Men 511 Slim Fit Jeans', 1478.0, 2899.0, 0.49, 4.3, 264.0)
# ('HERE&NOW', 'Men Stretchable Jeans', 798.0, 1699.0, 0.53, 4.0, 33.0)
# ('Urbano Fashion', 'Men Relaxed Fit Jeans', 944.0, 2099.0, 0.55, 4.0, 4200.0)
# ('WROGN', 'Men Anti Fit Jeans', 1623.0, 2799.0, 0.42, 4.2, 42.0)
# ('Bene Kleed', 'Men Wide Leg Heavy Fade Jeans', 839.0, 2799.0, 0.7, 3.6, 114.0)
# ('Bene Kleed', 'Relaxed Fit Denim Jeans', 873.0, 2299.0, 0.62, 4.1, 5200.0)
# ('Roadster', 'Men Regular Fit Mid-Rise Jeans', 759.0, 1899.0, 0.6, 4.0, 63.0)
# ('Bene Kleed', 'Men Bootcut Jeans', 873.0, 2299.0, 0.62, 4.0, 757.0)
# ('Bene Kleed', 'Men Wide Leg Jeans', 857.0, 2599.0, 0.67, 3.6, 152.0)
# ...

# %%
import pandas as pd
df=pd.read_sql("select * from myntra_dataset_byscraping",mydb)
df
# Out:
# C:\Users\PRINCE PANPALIYA\AppData\Local\Temp\ipykernel_5496\2110343043.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql("select * from myntra_dataset_byscraping",mydb)
#          brand_name             pants_description   price     MRP  \
# 0             WROGN    Men Loose Fit Cotton Jeans  1374.0  2499.0
# 1    Flying Machine            Men Slim Fit Jeans  1829.0  2999.0
# 2          Roadster         Men Pure Cotton Jeans   974.0  2499.0
# 3        Bene Kleed       Relaxed Fit Denim Jeans   873.0  2299.0
# 4             Levis        Men 511 Slim Fit Jeans  1478.0  2899.0
# ..              ...                           ...     ...     ...
# 288          Sztori   Plus Size Stretchable Jeans   863.0  2699.0
# 289        HERE&NOW             Men Bootcut Jeans   869.0  2499.0
# ...

# %%
🔹 10 Pandas Analysis Questions

# %%
# 1.How many unique brands are there in the dataset?

df['brand_name'].nunique()
# Out:
# 34

# %%
# 2. Which top 10 brands have the highest number of products listed?

df['brand_name'].value_counts().head(10)
# Out:
# brand_name
# Roadster                34
# Bene Kleed              32
# Flying Machine          31
# Mufti                   27
# Mast & Harbour          25
# Urbano Fashion          19
# WROGN                   17
# The Indian Garage Co    16
# glitchez                13
# HIGHLANDER              12
# Name: count, dtype: int64

# %%
# 3. What is the average price of products for each brand?

df.groupby('brand_name')['price'].mean()
df.sort_values(by="price",ascending=False)
# Out:
#             brand_name               pants_description   price     MRP  \
# 101              TURMS           30 Days No Wash Jeans  3499.0  4999.0
# 22      Flying Machine           Men Relaxed Fit Jeans  2309.0  3499.0
# 214     Flying Machine           Men Relaxed Fit Jeans  2309.0  3499.0
# 251              Mufti            Men Skinny Fit Jeans  2149.0  4299.0
# 59               Mufti            Men Skinny Fit Jeans  2149.0  4299.0
# ..                 ...                             ...     ...     ...
# 54          HIGHLANDER    Men Cotton Relaxed Fit Jeans   574.0  2299.0
# 130  Stylecast X Kotty          Men Regular Fit  Jeans   559.0  1999.0
# 188  Stylecast X Kotty  Men Regular Fit Mid-Rise Jeans   559.0  1999.0
# 218              Kotty              Men Low-Rise Jeans   519.0  1999.0
# 26               Kotty              Men Low-Rise Jeans   519.0  1999.0
#
#      discount_percent  ratings  number_of_ratings
# 101             15.00      3.7               22.0
# ...

# %%
# 4. Which category has the maximum number of products?

df['pants_description'].max()
# Out:
# 'Wide Leg Medium Shade Jeans'

# %%
# 5. Which brand offers the highest average discount? (min. 10 products)

df.groupby('brand_name')['discount_percent'].mean().sort_values(ascending=False).head(10)
# Out:
# brand_name
# Red Tape             25.840000
# TURMS                15.000000
# Thomas Scott         11.341667
# HERE&NOW              8.503333
# Mast & Harbour        3.646000
# HIGHLANDER            3.360000
# MAAHIT                0.770000
# FUDE PRIDE            0.770000
# Stylecast X Kotty     0.720000
# Dennis Lingo          0.690000
# Name: discount_percent, dtype: float64

# %%
# 6. Find the top 5 highest-rated products (ratings + rating_count)

df.sort_values(['ratings','number_of_ratings'], ascending=[False,False]).head(5)
# Out:
#          brand_name      pants_description   price     MRP  discount_percent  \
# 53            Mufti   Men Skinny Fit Jeans  1762.0  4299.0              0.59
# 245           Mufti   Men Skinny Fit Jeans  1762.0  4299.0              0.59
# 120           WROGN  Men Relaxed Fit Jeans  1049.0  2999.0              0.65
# 1    Flying Machine     Men Slim Fit Jeans  1829.0  2999.0              0.39
# 193  Flying Machine     Men Slim Fit Jeans  1829.0  2999.0              0.39
#
#      ratings  number_of_ratings
# 53       4.9                7.0
# 245      4.9                7.0
# 120      4.6               23.0
# 1        4.6                5.0
# 193      4.6                5.0

# %%
# 7. Find the price range (min, max) for each brand.
df.groupby('brand_name')['discount_percent'].agg(['mean','max'])
# Out:
#                             mean    max
# brand_name
# Being Human             0.580000   0.58
# Bene Kleed              0.648750   0.75
# Calvin Klein Jeans      0.620000   0.62
# Dennis Lingo            0.690000   0.69
# FUDE PRIDE              0.770000   0.77
# FUGAZEE                 0.400000   0.40
# Flying Machine          0.389032   0.45
# French Connection       0.630000   0.63
# HERE&NOW                8.503333  16.70
# HIGHLANDER              3.360000  17.00
# Kotty                   0.685000   0.74
# Levis                   0.476667   0.55
# MAAHIT                  0.770000   0.77
# MASTERLY WEFT           0.520000   0.52
# Mast & Harbour          3.646000  21.30
# Mufti                   0.585556   0.73
# Nautica                 0.640000   0.67
# PARIS HAMILTON          0.550000   0.55
# Peter England Casuals   0.400000   0.40
# Red Tape               25.840000  50.88
# Roadster                0.640588   0.74
# Style Quotient          0.660000   0.66
# ...

# %%
# 8. Find products where discount percentage is greater than 70%.

df[df['discount_percent'] > 20]
# Out:
#          brand_name     pants_description   price     MRP  discount_percent  \
# 32   Mast & Harbour     Men Bootcut Jeans   869.0  2999.0             21.30
# 124        Red Tape  Men Skinny Fit Jeans  1311.0  6399.0             50.88
# 154    Thomas Scott  Men Clean Look Jeans   819.0  3299.0             24.80
# 180    Thomas Scott     Men Bootcut Jeans   999.0  3499.0             25.00
# 224  Mast & Harbour     Men Bootcut Jeans   869.0  2999.0             21.30
#
#      ratings  number_of_ratings
# 32       4.1              211.0
# 124      4.1              359.0
# 154      4.0              220.0
# 180      3.9              401.0
# 224      4.1              211.0

# %%
# 9. Show all products with rating = 5.0 (perfect rating).

df[df['ratings'] == 4.5]
# Out:
#          brand_name       pants_description   price     MRP  discount_percent  \
# 76          Nautica      Men Slim Fit Jeans  1088.0  3299.0              0.67
# 105           WROGN      Men Slim Fit Jeans   919.0  2299.0              0.60
# 126  Mast & Harbour  Men Straight Fit Jeans   764.0  1699.0              0.55
# 268         Nautica      Men Slim Fit Jeans  1088.0  3299.0              0.67
#
#      ratings  number_of_ratings
# 76       4.5               30.0
# 105      4.5               15.0
# 126      4.5               33.0
# 268      4.5               30.0

# %%
# 10. What is the correlation between product price and discount percentage?

df[['price','discount_percent']].corr()
# Out:
#                      price  discount_percent
# price             1.000000          0.001975
# discount_percent  0.001975          1.000000
